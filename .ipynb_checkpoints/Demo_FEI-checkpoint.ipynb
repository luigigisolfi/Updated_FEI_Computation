# %% [markdown]
# # FRAGMENTATION INDEX COMPUTATION
#
# ## Objectives
# This code shows how to use functions in the `fei_library.py` file in order to compute the (Upgraded) Fragmentation Environmental Index, as devised in [L. Gisolfi Master's Thesis](https://thesis.unipd.it/retrieve/b00fb71a-4118-444b-bb0e-3ab77846ce05/Gisolfi_Luigi.pdf.pdf).
#
# **Author**: Luigi Gisolfi
#
# **Year**: 2025
#
#
# Please, create the folder nube_XXX_km with the all the files nube_XXX_km/data/cloud_XXX.fla
# Make sure you have access to the file dens_mean_no_weights_2023.dat
# Note: For the background, only MASTER population objects > 5 cm is considered (file: background_pop.dat.5cm) has to be used as input

# %% [markdown]
# ## Import Statements
# Let's start by importing some relevant python modules that will be useful for the computation.

# %%
from fei_library import ComputeFEI
import os
object = ComputeFEI()

# %% [markdown]
# ## Set Parent Objects Properties
#
# The `SetParent` class allows users to store the Parent's eccentricity and inclination (in degrees), as well as its mass (in kg).
# Of course, these must match the properties of the object that underwent fragmentation.

# %%
parent_mass = object.SetParent.mass(mass = 2000)
parent_e = object.SetParent.eccentricity(parent_e = 0.00003)
parent_inc = object.SetParent.inclination(parent_inc = 80.3)

# %% [markdown]
# ## Retrieve h_frag
#
# Each cloud folder is named after the given fragmentation altitude (nube_XXX_km, where XXX indicates the fragmentation altitude. Also, "nube" is the word for "cloud" in italian!), so we use this fact to retrieve the correspoding fragmentation altitude, $h_{frag}$.

# %%
cloud_name = 'nube_450_km'
h_frag = float(cloud_name.split('_')[1])
h_frag = object.SetFragmentation.fragmentation_altitude(h_frag = h_frag)

# %% [markdown]
# ## Observing Network Settings
#
# The `SetObservingNetwork` class allows to set the minimum observable size $s_{min}$ at a given reference altitude $h_{max}$.
# Setting the network elevation is also possible and achieved via the `SetObservingNetwork.constant_elevation` metho (the elevation could in prinicple be time dependent, but no time dependent elevation method has been developed yet...)

# %%
s_min = object.SetObservingNetwork.s_min(s_min = 25)
elevation = object.SetObservingNetwork.constant_elevation(elevation = 30)

# %% [markdown]
# ## Background Population File
#
# At this point, the background population file path has to be specified.

# %%
background_population_file = 'background_pop.dat.5cm'
clouds_folder_path = 'clouds'

# %% [markdown]
# ## Network Type Automatic Selection
#
# As explained in [L. Gisolfi Master's Thesis](https://thesis.unipd.it/retrieve/b00fb71a-4118-444b-bb0e-3ab77846ce05/Gisolfi_Luigi.pdf.pdf), we assume radar can probe LEO from the lowest shells up to (excluded) $h_{max} = 1200$ km, while optical networks are active between $h = 1200$ km and $h_{max} = 2000$ km.

# %%
if h_frag < 1200:
    network_type = 'radar'
else:
    network_type = 'optical'

# %% [markdown]
# ## Computing Relevant Quantities for Subsequent Analysis
# We are now ready to compute the global csi, the cloud csi and other quantities. These will allow us to compute the FEI.
# We:
# - compute the weighted and unweighted CSI contributions to the background population (as it was before the fragmentation epioch, given the background population file defined above)
# - compute the weighted and unweighted CSI contributions of all objects after the fragmentation.
#
# Relevant values are saved to files in the `nube_XXX_km/output` folders.

# %%
if network_type == 'radar':
    color_plot = 'red'
    h_max = object.SetObservingNetwork.h_max(h_max = 1200)
    pieces_of_strings = ['_5cm_1200km','_15cm_1200km','_20cm_1200km' ]
else:
    color_plot = 'black'
    h_max = object.SetObservingNetwork.h_max(h_max = 2000)
    pieces_of_strings = ['_5cm_2000km','_15cm_2000km','_20cm_2000km' ]

piece_of_string = '_' + str(round(s_min)) + 'cm_' + str(round(h_max)) + 'km'
cloud_folder_path = os.path.join(clouds_folder_path, cloud_name)
output_folder_path = os.path.join(cloud_folder_path, 'output')
figures_folder = os.path.join(output_folder_path, 'figures')
global_csi_folder = os.path.join(output_folder_path, 'global_csi')
csi_cloud_only_folder = os.path.join(output_folder_path, 'cloud_only_csi')

if network_type == 'radar':

    object.radar_background(cloud_name,
                            h_frag, 
                            piece_of_string, 
                            background_population_file
                           )
    
    day_list, global_csi_cloud_only_list, global_csi_cloud_only_list_no_weights, global_csi_list,global_csi_list_no_weights, ratios_list = object.radar(parent_mass, 
                                                                                                                                                        parent_e, 
                                                                                                                                                        parent_inc, 
                                                                                                                                                        cloud_name, 
                                                                                                                                                        h_frag, 
                                                                                                                                                        elevation, 
                                                                                                                                                        s_min, 
                                                                                                                                                        h_max, 
                                                                                                                                                        piece_of_string)
else:
    object.optical_background(cloud_name, h_frag, piece_of_string, background_population_file)
    day_list, global_csi_cloud_only_list, global_csi_cloud_only_list_no_weights, global_csi_list,global_csi_list_no_weights, ratios_list = object.optical(parent_mass, 
                                                                                                                                                          parent_e, 
                                                                                                                                                          parent_inc, 
                                                                                                                                                          cloud_name, 
                                                                                                                                                          h_frag, 
                                                                                                                                                          elevation, 
                                                                                                                                                          s_min, 
                                                                                                                                                          h_max, 
                                                                                                                                                          piece_of_string)

print('Done processing.')
# Out:
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:376: RuntimeWarning: divide by zero encountered in divide
#   E_out = np.arccos((a - r_out)/(a*e)) #E_out of selected objects only
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:376: RuntimeWarning: invalid value encountered in arccos
#   E_out = np.arccos((a - r_out)/(a*e)) #E_out of selected objects only
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:377: RuntimeWarning: divide by zero encountered in divide
#   E_in = np.arccos((a - r_in)/(a*e))#E_in of selected objects only
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:377: RuntimeWarning: invalid value encountered in arccos
#   E_in = np.arccos((a - r_in)/(a*e))#E_in of selected objects only
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:376: RuntimeWarning: invalid value encountered in divide
#   E_out = np.arccos((a - r_out)/(a*e)) #E_out of selected objects only
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:377: RuntimeWarning: invalid value encountered in divide
#   E_in = np.arccos((a - r_in)/(a*e))#E_in of selected objects only
# The minimum detectable size for a fragment at 450.0 km is: 22.34 cm
#
# Folder already exists: clouds/nube_450_km
# Folder already exists: clouds/nube_450_km/csi_background
# Folder already exists: clouds/nube_450_km/data
# Folder already exists: clouds/nube_450_km/output
# Folder already exists: clouds/nube_450_km/output/weights/radar_25cm_1200km
# Folder already exists: clouds/nube_450_km/output/figures/radar_25cm_1200km
# Folder already exists: clouds/nube_450_km/output/csi_post_pre/radar_25cm_1200km
# Folder already exists: clouds/nube_450_km/output/array_shells_ratios/radar_25cm_1200km
# Folder already exists: clouds/nube_450_km/output/global_csi/radar_25cm_1200km
# Folder already exists: clouds/nube_450_km/output/cloud_only_csi/radar_25cm_1200km
# Folder already exists: clouds/nube_450_km/output/cloud_only_csi/radar_25cm_1200km
# Processing cloud file: cloud_061.fla
# Processing cloud file: cloud_075.fla
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:425: RuntimeWarning: invalid value encountered in arccos
#   E_out_par = np.arccos((a - r_out)/(a*e))
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:426: RuntimeWarning: invalid value encountered in arccos
#   E_in_par = np.arccos((a - r_in)/(a*e))
# Processing cloud file: cloud_049.fla
# Processing cloud file: cloud_100.fla
# Processing cloud file: cloud_048.fla
# Processing cloud file: cloud_074.fla
# Processing cloud file: cloud_060.fla
# Processing cloud file: cloud_076.fla
# Processing cloud file: cloud_062.fla
# Processing cloud file: cloud_089.fla
# Processing cloud file: cloud_088.fla
# Processing cloud file: cloud_063.fla
# Processing cloud file: cloud_077.fla
# Processing cloud file: cloud_073.fla
# Processing cloud file: cloud_067.fla
# Processing cloud file: cloud_098.fla
# Processing cloud file: cloud_099.fla
# Processing cloud file: cloud_066.fla
# Processing cloud file: cloud_072.fla
# Processing cloud file: cloud_058.fla
# Processing cloud file: cloud_064.fla
# Processing cloud file: cloud_070.fla
# Processing cloud file: cloud_071.fla
# Processing cloud file: cloud_065.fla
# Processing cloud file: cloud_059.fla
# Processing cloud file: cloud_002.fla
# Processing cloud file: cloud_016.fla
# Processing cloud file: cloud_017.fla
# Processing cloud file: cloud_003.fla
# Processing cloud file: cloud_015.fla
# Processing cloud file: cloud_001.fla
# Processing cloud file: cloud_029.fla
# Processing cloud file: cloud_028.fla
# Processing cloud file: cloud_014.fla
# Processing cloud file: cloud_038.fla
# Processing cloud file: cloud_010.fla
# Processing cloud file: cloud_004.fla
# Processing cloud file: cloud_005.fla
# Processing cloud file: cloud_011.fla
# Processing cloud file: cloud_039.fla
# Processing cloud file: cloud_007.fla
# Processing cloud file: cloud_013.fla
# Processing cloud file: cloud_012.fla
# Processing cloud file: cloud_006.fla
# Processing cloud file: cloud_023.fla
# Processing cloud file: cloud_037.fla
# Processing cloud file: cloud_036.fla
# Processing cloud file: cloud_022.fla
# Processing cloud file: cloud_034.fla
# Processing cloud file: cloud_020.fla
# Processing cloud file: cloud_008.fla
# Processing cloud file: cloud_009.fla
# Processing cloud file: cloud_021.fla
# Processing cloud file: cloud_035.fla
# Processing cloud file: cloud_019.fla
# Processing cloud file: cloud_031.fla
# Processing cloud file: cloud_025.fla
# Processing cloud file: cloud_024.fla
# Processing cloud file: cloud_030.fla
# Processing cloud file: cloud_018.fla
# Processing cloud file: cloud_026.fla
# Processing cloud file: cloud_032.fla
# Processing cloud file: cloud_033.fla
# Processing cloud file: cloud_027.fla
# Processing cloud file: cloud_040.fla
# Processing cloud file: cloud_054.fla
# Processing cloud file: cloud_068.fla
# Processing cloud file: cloud_083.fla
# Processing cloud file: cloud_097.fla
# Processing cloud file: cloud_096.fla
# Processing cloud file: cloud_082.fla
# Processing cloud file: cloud_069.fla
# Processing cloud file: cloud_055.fla
# Processing cloud file: cloud_041.fla
# Processing cloud file: cloud_057.fla
# Processing cloud file: cloud_043.fla
# Processing cloud file: cloud_094.fla
# Processing cloud file: cloud_080.fla
# Processing cloud file: cloud_081.fla
# Processing cloud file: cloud_095.fla
# Processing cloud file: cloud_042.fla
# Processing cloud file: cloud_056.fla
# Processing cloud file: cloud_052.fla
# Processing cloud file: cloud_046.fla
# Processing cloud file: cloud_091.fla
# Processing cloud file: cloud_085.fla
# Processing cloud file: cloud_084.fla
# Processing cloud file: cloud_090.fla
# Processing cloud file: cloud_047.fla
# Processing cloud file: cloud_053.fla
# Processing cloud file: cloud_079.fla
# Processing cloud file: cloud_045.fla
# Processing cloud file: cloud_051.fla
# Processing cloud file: cloud_086.fla
# Processing cloud file: cloud_092.fla
# Processing cloud file: cloud_093.fla
# Processing cloud file: cloud_087.fla
# Processing cloud file: cloud_050.fla
# Processing cloud file: cloud_044.fla
# Processing cloud file: cloud_078.fla
# Done processing.

# %% [markdown]
# ## Plotting the Results
# Finally, the CSI and FEI values are plotted (using the `plotter_csi()`, `plotter_FEI()` and `multi_potter_csi()` methods), and the **cumulative index** file corresponding to the given fragmentation and network is created via `get_cumulative_index_files()`.

# %%
object.plotter_csi(network_type, color_plot, day_list, global_csi_cloud_only_list, global_csi_cloud_only_list_no_weights, global_csi_list, s_min, clouds_folder_path, cloud_name, piece_of_string)
object.plotter_FEI(network_type,color_plot, clouds_folder_path, cloud_name, piece_of_string, h_frag)
object.multi_plotter_csi(pieces_of_strings, cloud_name, network_type, figures_folder, global_csi_folder, csi_cloud_only_folder)
object.get_cumulative_index_files(output_folder_path, network_type, piece_of_string)
# Out:
# _5cm_1200km red
# _15cm_1200km grey
# _20cm_1200km black
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:1207: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig1.show()
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:1215: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()
# /Users/lgisolfi/CLionProjects/FEI/fei_library.py:1222: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig3.show()

# %% [markdown]
# ## Cumulative Index: How To Plot It
# After running the above cells for all fragmentations altitudes (i.e. 450 km, 800 km, 1200 km, 1800 km) and for different networks (for instance, setting $s_{min} = 5,10,15,20,25$ cm) the user would be able to get the cumulative index plots via the following (commented for now) lines:

# %%
#cloud_names = ['nube_1200_km', 'nube_1800_km']
#network_type = 'optical'
#object.plot_cumulative_indexes(clouds_folder_path, network_type, cloud_names)
